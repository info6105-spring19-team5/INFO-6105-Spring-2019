# %%
import autosklearn.classification
import sklearn.model_selection
import sklearn.metrics
import pandas as pd

load_digits = pd.read_csv("Cleaned_loan1.csv")

X, y = sklearn.datasets.load_digits(return_X_y=True)

X_train, X_test, y_train, y_test = \
        sklearn.model_selection.train_test_split(X, y, random_state=1)
automl = autosklearn.classification.AutoSklearnClassifier()
automl.fit(X_train, y_train)
y_hat = automl.predict(X_test)
print("Accuracy score", sklearn.metrics.accuracy_score(y_test, y_hat))
# Out:
# /Users/nikitagawde/anaconda3/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# [WARNING] [2019-03-22 17:29:21,660:EnsembleBuilder(1):d74860caaa557f473ce23908ff7ba369] No models better than random - using Dummy Score!
# [WARNING] [2019-03-22 17:29:21,677:EnsembleBuilder(1):d74860caaa557f473ce23908ff7ba369] No models better than random - using Dummy Score!
# /Users/nikitagawde/anaconda3/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /Users/nikitagawde/anaconda3/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# Exception ignored in: <function BackendContext.__del__ at 0x10883a7b8>
# Traceback (most recent call last):
# ...

# %%
import pandas as pd
import numpy as np
test_df = pd.read_csv('Cleaned_loan1.csv', low_memory =False)

# %% [markdown]
# # AUTO SKLEARN

# %% [markdown]
#  It's an automated machine learning method which does algorithm selection and hyperparameter tuning. It requires python module "resource" mainly.

# %% [markdown]
# ### The system requirements are :
# 1. Linux operating system
# 2. Python (>=3.5)
# 3. C++ Complier
# 4. Swig  (version 3.0 or later)

# %% [markdown]
# The main thing which makes the auto sklearn stand out is that it takes less resources than sklearn estimator method. It allows the user to inspect the training results and statistics.
# The code runs for one hour because it is sequential in nature and uses Bayesian optimization method for hyperparameter tuning but has an accuracy of over 98%.
# The dataset was divided into training set and testing set. AutoSKlearnClassifier( ) is the main function which does the permutations.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split  
 

X_train = train_df.drop("int_rate", axis=1)
y_train = train_df["int_rate"]
X_test  = test_df.drop("int_rate", axis=1).copy()

X_train, X_test, y_train, y_test = \
        sklearn.model_selection.train_test_split(X, y, random_state=1)

automl = autosklearn.classification.AutoSklearnClassifier()
automl.fit(X_train, y_train)
y_hat = automl.predict(X_test)

print("Accuracy score", sklearn.metrics.accuracy_score(y_test, y_hat))
# Out:
# /Users/nikitagawde/anaconda3/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# [WARNING] [2019-03-22 18:19:31,778:EnsembleBuilder(1):d74860caaa557f473ce23908ff7ba369] No models better than random - using Dummy Score!
# [WARNING] [2019-03-22 18:19:31,794:EnsembleBuilder(1):d74860caaa557f473ce23908ff7ba369] No models better than random - using Dummy Score!
# /Users/nikitagawde/anaconda3/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /Users/nikitagawde/anaconda3/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# ...

# %%
import time
import pandas as pd
import numpy as np

input_data = pd.read_csv("Cleaned_loan1.csv")

import sklearn.model_selection

# split data into X and y
y_df = input_data['int_rate'].copy()
X_df = input_data.copy()
X_df.drop('int_rate', axis=1, inplace=True)

from sklearn.model_selection import GridSearchCV, train_test_split
#X_train, X_test, y_train, y_test = train_test_split(X_df.values, 
                                                    #y_df.values,
                                                    #test_size=0.2,
                                                    #random_state=42,
                                                    #shuffle=True)

target =df["int_rate"]
X_train, X_test, y_train, y_test = train_test_split(df, target, test_size=0.5)
X_test,X_dev,y_test,y_dev = train_test_split(X_test,y_test, test_size=0.5)

# %%
import autosklearn.regression

automl = autosklearn.regression.AutoSklearnRegressor(
    time_left_for_this_task=3600,
    per_run_time_limit=300,
    ml_memory_limit=10240,
    tmp_folder='./autosklearn_ccs_tmp',
    output_folder='./autosklearn_ccs_tmp_out',
    delete_tmp_folder_after_terminate=False,
    delete_output_folder_after_terminate=False)

automl.fit(X_train, y_train, dataset_name='Cleaned_loan1')
# Out:
# /Users/nikitagawde/anaconda3/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# [WARNING] [2019-03-22 21:27:19,750:AutoMLSMBO(1)::Cleaned_loan1] Could not find meta-data directory /Users/nikitagawde/anaconda3/lib/python3.7/site-packages/autosklearn/metalearning/files/r2_regression_dense
# [WARNING] [2019-03-22 21:27:19,801:EnsembleBuilder(1):Cleaned_loan1] No models better than random - using Dummy Score!
# [WARNING] [2019-03-22 21:27:19,842:EnsembleBuilder(1):Cleaned_loan1] No models better than random - using Dummy Score!
# /Users/nikitagawde/anaconda3/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /Users/nikitagawde/anaconda3/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
# ...

# %%
import autosklearn.classification
import sklearn.model_selection
import sklearn.datasets
import sklearn.metrics

# %%
X, y = sklearn.datasets.load_digits(return_X_y=True)
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, random_state=1)
automl = autosklearn.classification.AutoSklearnClassifier()
automl.fit(X_train, y_train)
y_hat = automl.predict(X_test)
print("Score of Accuracy", sklearn.metrics.accuracy_score(y_test, y_hat))
# Out:
# /Users/nikitagawde/anaconda3/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# [WARNING] [2019-03-22 19:19:59,983:EnsembleBuilder(1):d74860caaa557f473ce23908ff7ba369] No models better than random - using Dummy Score!
# [WARNING] [2019-03-22 19:20:00,008:EnsembleBuilder(1):d74860caaa557f473ce23908ff7ba369] No models better than random - using Dummy Score!
# /Users/nikitagawde/anaconda3/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /Users/nikitagawde/anaconda3/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# ...

# %%
import autosklearn.classification
import pandas as pd

df = pd.read_csv("Cleaned_loan1.csv")
X_train =('int_rate', axis=1, inplace=True)


cls = autosklearn.classification.AutoSklearnClassifier()
cls.fit(X_train, y_train)
y_hat = cls.predict(X_test)
